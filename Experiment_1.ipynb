# %% [markdown]
# # Experiment on simulations n°1 - Convergence of cVAE-OSM weights: leakage model and variance extraction (see Section 5.1.2)

# %% [markdown]
# ## Outline
#
# [Content](#content)
#
# [Prerequisite packages and settings](#prerequisite-packages-and-settings)
#
# [Step 1: Traces generation](#step-1)
#
# [Step 2: Instanciation of a cVAE-OSM model](#step-2)
#
# [Step 3: Training of cVAE-OSM model](#step-3)
#
# [Step 4: Visualization of leakage models extracted by the model](#step-4)

# %% [markdown]
# ## Content <a class='anchor' id='content'></a>

# %% [markdown]
# In this notebook, we propose to conduct the first experiment of our paper (see Section 5.1.2), in which we assess the convergence of cVAE-OSM weights using simulations.
# To do so, we first generate traces, then instanciate and train a cVAE-OSM model. Finally, according to parameters estimated by our model, we assess its weights convergence.

# %% [markdown]
# ## Prerequisite packages and settings <a class='anchor' id='prerequisite-packages-and-settings'></a>

# %% [markdown]
# Here are the Python packages and settings needed to run properly this notebook.

# %%
from cvae_osm_utils.generate_traces import *
from cvae_osm_utils.cVAE_OSM_model import *
from cvae_osm_utils.cVAE_OSM_tools import *
from matplotlib import pyplot as plt

# Enables Tensorflow program to run deterministically for reproducible results
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

plt.rcParams['text.usetex'] = True
# Out:
# WARNING:tensorflow:From c:\Users\bouss\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Step 1: Traces generation <a class='anchor' id='step-1'></a>

# %% [markdown]
# The generation of traces is done using a function called $\texttt{generate\_traces}$, available in $\texttt{generate\_traces.py}$ file.
#
# In the following example, we generate $20,000$ traces of $150$ samples such that $10\%$ are PoIs. We consider the fourth scenario with an isotropic Gaussian noise of parameters $\mu=0$ and $\sigma=5$.
# The targeted byte is $0$ and the key is fixed. We set the seed to $42$ to have reproductible results.

# %%
# Traces generation
targeted_byte = 0

traces, plaintexts, keys, targeted_variables, sigmas = generate_traces(nb_traces=20000, nb_samples=150, nb_poi=15, mu=0, sigmas=np.array([5]), targeted_byte=targeted_byte, \
                        isotropic_noise=True, scenario='scenario_4', key_fixed=True, seed=42)

print("Traces generated \U00002705")
# Out:
# Traces generated ✅

# %% [markdown]
# Here is an example of generated traces.

# %%
# Plot of a trace
plt.plot(traces[0,:])
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# ## Step 2: Instanciation of a cVAE-OSM model <a class='anchor' id='step-2'></a>

# %% [markdown]
# After generating traces, we instanciate a cVAE-OSM model. As for traces generation, to enable reproductible results, we set the seed to a fixed value. In this case, we choose $\texttt{seed}=42$.
#
# Considering a learning rate set to $0.0001$, we instanciate a cVAE-OSM by calling $\texttt{cVAE}$ class (see $\texttt{cVAE\_OSM\_model.py}$ file) and compile the model.

# %%
# Instanciation of encoder and decoder
nb_samples = traces.shape[1]
learning_rate = 0.0001
max_nb_monomials_interactions, len_basis = 8, 256

encoder = define_encoder(input_size=nb_samples, len_basis=len_basis, is_deterministic=True, seed=42)
decoder = define_decoder(input_size=nb_samples, len_basis=len_basis, is_deterministic=True, seed=42)

# Instanciation of cVAE-OSM model
cVAE_OSM = cVAE(encoder, decoder)

# Compilation of cVAE-OSM model
cVAE_OSM.compile(optimizer=keras.optimizers.Adam(learning_rate))

print("Model created \U00002705")
# Out:
# WARNING:tensorflow:From c:\Users\bouss\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model created ✅

# %% [markdown]
# ## Step 3: Training of cVAE-OSM model <a class='anchor' id='step-3'></a>

# %% [markdown]
# Once the model is created, we train our model using simulated traces and the projection of targeted variables into the orthonormal basis.
#
# The projection of targeted variables onto Guilley *et al.* basis is computed using $\texttt{orthonormal\_basis\_projection}$ function, which is available in $\texttt{cVAE\_OSM\_tools.py}$ file. We consider all bits interactions, thus $\texttt{len\_basis}=256$.

# %%
# Projection of target variables onto Guilley etal. orthonormal basis
# We consider the full basis (len_basis=256) i.e. all the monomials len_basis=256
# One can also consider other configurations
# For example, when considering only the monomials individually i.e. without interactions between them, len_basis=9
projection_targeted_variables = orthonormal_basis_projection(targeted_variables[:, targeted_byte], max_nb_monomials_interactions, len_basis)

print("Projection done \U00002705")
# Out:
# Projection done ✅

# %% [markdown]
# Then, training is done for $200$ epochs using a batch size set to $8$.

# %%
# cVAE-OSM training
batch_size = 8
epochs = 200

cVAE_OSM.fit([traces, projection_targeted_variables], epochs=epochs, batch_size=batch_size)

print("Training done \U00002705")
# Out:
# Epoch 1/200
# 2500/2500 [==============================] - 6s 2ms/step - ELBO loss: 24824.0331 - reconstruction_loss: 1945.5530 - kl_loss: 20233.1660
# Epoch 2/200
# 2500/2500 [==============================] - 6s 2ms/step - ELBO loss: 15101.8981 - reconstruction_loss: 1548.6862 - kl_loss: 11673.8467
# Epoch 3/200
# 2500/2500 [==============================] - 5s 2ms/step - ELBO loss: 8213.0237 - reconstruction_loss: 1179.4655 - kl_loss: 5736.9800
# Epoch 4/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 3679.3220 - reconstruction_loss: 845.2261 - kl_loss: 2075.1609
# Epoch 5/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 1249.4917 - reconstruction_loss: 579.8188 - kl_loss: 378.7260
# Epoch 6/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 496.5952 - reconstruction_loss: 464.4008 - kl_loss: 10.1780
# Epoch 7/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.8872 - reconstruction_loss: 458.2573 - kl_loss: 0.4964
# Epoch 8/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.8102 - reconstruction_loss: 458.2344 - kl_loss: 0.4967
# Epoch 9/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.6143 - reconstruction_loss: 458.1985 - kl_loss: 0.4966
# Epoch 10/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.5673 - reconstruction_loss: 458.1615 - kl_loss: 0.4959
# Epoch 11/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.7881 - reconstruction_loss: 458.1226 - kl_loss: 0.4941
# Epoch 12/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.6147 - reconstruction_loss: 458.0879 - kl_loss: 0.4923
# Epoch 13/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.5768 - reconstruction_loss: 458.0489 - kl_loss: 0.4911
# Epoch 14/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.4943 - reconstruction_loss: 458.0138 - kl_loss: 0.4889
# Epoch 15/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.4842 - reconstruction_loss: 457.9767 - kl_loss: 0.4872
# Epoch 16/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458.4673 - reconstruction_loss: 457.9402 - kl_loss: 0.4854
# Epoch 17/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 458
200
# 2500/2500 [==============================] - 13s 5ms/step - ELBO loss: 454.7612 - reconstruction_loss: 454.4713 - kl_loss: 0.3026
# Epoch 180/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 454.7738 - reconstruction_loss: 454.4629 - kl_loss: 0.3018
# Epoch 181/200
# 2500/2500 [==============================] - 13s 5ms/step - ELBO loss: 454.6936 - reconstruction_loss: 454.4507 - kl_loss: 0.3020
# Epoch 182/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 454.7319 - reconstruction_loss: 454.4406 - kl_loss: 0.3003
# Epoch 183/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.7313 - reconstruction_loss: 454.4273 - kl_loss: 0.3007
# Epoch 184/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.6880 - reconstruction_loss: 454.4181 - kl_loss: 0.2997
# Epoch 185/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.6639 - reconstruction_loss: 454.4066 - kl_loss: 0.2995
# Epoch 186/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.7400 - reconstruction_loss: 454.3969 - kl_loss: 0.2985
# Epoch 187/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.7382 - reconstruction_loss: 454.3846 - kl_loss: 0.2977
# Epoch 188/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.6546 - reconstruction_loss: 454.3753 - kl_loss: 0.2981
# Epoch 189/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.6564 - reconstruction_loss: 454.3650 - kl_loss: 0.2968
# Epoch 190/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.7155 - reconstruction_loss: 454.3535 - kl_loss: 0.2961
# Epoch 191/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 454.5857 - reconstruction_loss: 454.3456 - kl_loss: 0.2961
# Epoch 192/200
# 2500/2500 [==============================] - 11s 4ms/step - ELBO loss: 454.6432 - reconstruction_loss: 454.3336 - kl_loss: 0.2954
# Epoch 193/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.6092 - reconstruction_loss: 454.3232 - kl_loss: 0.2955
# Epoch 194/200
# 2500/2500 [==============================] - 11s 4ms/step - ELBO loss: 454.5932 - reconstruction_loss: 454.3138 - kl_loss: 0.2944
# Epoch 195/200
# 2500/2500 [==============================] - 11s 5ms/step - ELBO loss: 454.6296 - reconstruction_loss: 454.3043 - kl_loss: 0.2936
# Epoch 196/200
# 2500/2500 [==============================] - 12s 5ms/step - ELBO loss: 454.6241 - reconstruction_loss: 454.2932 - kl_loss: 0.2934
# Epoch 197/200
# 2500/2500 [==============================] - 14s 5ms/step - ELBO loss: 454.5409 - reconstruction_loss: 454.2833 - kl_loss: 0.2926
# Epoch 198/200
# 2500/2500 [==============================] - 14s 6ms/step - ELBO loss: 454.5560 - reconstruction_loss: 454.2744 - kl_loss: 0.2923
# Epoch 199/200
# 2500/2500 [==============================] - 15s 6ms/step - ELBO loss: 454.4197 - reconstruction_loss: 454.2651 - kl_loss: 0.2918
# Epoch 200/200
# 2500/2500 [==============================] - 15s 6ms/step - ELBO loss: 454.6106 - reconstruction_loss: 454.2549 - kl_loss: 0.2906
# Training done ✅

# %% [markdown]
# ## Step 4: Visualization of leakage models extracted by the model <a class='anchor' id='step-4'></a>

# %% [markdown]
# Finally, we can visualize the deterministic parts estimated by our model *i.e.* $\hat{\Psi}_\phi$ and $\hat{\Psi}_\theta$, and compare them to the true leakage model.
#
# This visualization is done using $\texttt{weights\_visualization}$ function (see $\texttt{cVAE\_OSM\_tools.py}$ file).

# %%
# Weights visualization of deterministic part estimated by both encoder and decoder for all samples excluding the bias (we disable saving option)
discard_bias = True
weights_visualization(encoder, decoder, [i for i in range(nb_samples)], discard_bias=discard_bias, saving=False, path=None, filename=None)

# %% [markdown]
# We can visually compare the extracted leakage models with the true leakage model $\Psi$.
#
# To compute $\Psi$, we use $\texttt{orthonormal\_basis\_computation\_true\_coeffs}$ function (see $\texttt{cVAE\_OSM\_tools.py}$ file).

# %%
# Computation of an estimation of the real orthonormal basis coefficients
psi = orthonormal_basis_computation_true_coeffs(traces, targeted_variables[:, targeted_byte], max_nb_monomials_interactions)

# Plot of the true leakage model for all samples excluding the bias
for i in range(psi.shape[0]):
    plt.plot(psi[i,int(discard_bias):])

plt.title(r'True leakage model - $\Psi$ coefficients visualization')
plt.xlabel('Orthonormal basis')
plt.ylabel('Coefficients of the orthonormal basis')
plt.show()

# %% [markdown]
# We can also compare more formally leakage models $\hat{\Psi}_\phi$ and $\hat{\Psi}_\theta$ extracted by the model with the true leakage model $\Psi$ by using mean squared error (MSE).

# %%
# Getting back from the encoder and decoder the weights i.e. estimated deterministic parts
psi_phi = encoder.get_layer('psi_layer_encoder').weights[0].numpy()
psi_phi = psi_phi.T
psi_theta = decoder.get_layer('psi_layer_decoder').weights[0].numpy()
psi_theta = psi_theta.T

# Computation of MSE 
psi_phi_difference = np.subtract(psi, psi_phi)
psi_theta_difference = np.subtract(psi, psi_theta)
psi_phi_mse = np.mean(np.square(psi_phi_difference))
psi_theta_mse = np.mean(np.square(psi_theta_difference))

print("MSE(Psi, Psi_phi) = %.5f" % psi_phi_mse)
print("MSE(Psi, Psi_theta) = %.5f" % psi_theta_mse)
# Out:
# MSE(Psi, Psi_phi) = 1.70325
# MSE(Psi, Psi_theta) = 0.30482

# %% [markdown]
# Regarding $\boldsymbol{\Sigma}_\phi$, we can compute the approximation error for each sample.

# %%
# Getting back from the encoder the weights i.e. the inverse of the variance for each sample
encoder_inverse_variances = encoder.get_layer('z_mean').weights[0].numpy()
encoder_variances = 1/encoder_inverse_variances

# Computation of approximation errors
true_variances = sigmas**2
approx_errors = np.abs(np.subtract(true_variances,encoder_variances)/true_variances)
percent_errors = 100 * approx_errors

print("Mean of percent approximation errors: %.2f%%" % np.mean(percent_errors))
# Out:
# Mean of percent approximation errors: 3.69%

# %% [markdown]
# All the results obtained through this notebook are in line with those reported in Section 5.1.2.
#
# We observe that cVAE-OSM is able to correctly extract leakage model and variance of traces, even when considering a high noise. We obtain a low MSE value for $\Psi_\phi$ and  $\Psi_\theta$ estimation and the average of percent approximation errors does not exceed $4\%$ for $\boldsymbol{\Sigma}_\phi$ estimation.
#
# As shown in the results reported in Section 5.1.2, here again, we can notice a slight difference in the MSE value obtained for $\Psi_\phi$ and  $\Psi_\theta$. Indeed, $\Psi_\phi$  estimation induce a larger value of MSE than $\Psi_\theta$ estimation. This difference of MSE values can be explained by the fact that
# encoder weights are impacted by KL-divergence term minimization in the ELBO loss. This term relates to an approximation of the real distribution that follow monovariate traces $\mathbf{\tilde{T}}$ (see Remark 1). This can therefore explains why encoder weights "converge less precisely" than decoder weights.
